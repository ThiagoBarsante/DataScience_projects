# %% [markdown]
# ## Business Requirement
#
# - One Data Science project can start with a formal specification and many vendors can also participate in a commercial proposal
#
# - Sometimes can be just one slide from one presentation send by email to the analytics team (example below)

# %%
from IPython.display import Image
Image('../data/Business_Requirements-1-Customer-Support.PNG')
